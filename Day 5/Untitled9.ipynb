# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
x=[3,6,9]
y=[-3,5,9]
plt.title("our first graph")
plt.xlabel("company")
plt.ylabel("khan")
plt.xticks([2,4,6,8])
plt.yticks([1,3,5,7])
#FMT = '[color][marker][line]' short hand notations
plt.plot(x,y, 'b*-' , label ='2x')
plt.legend()



#line no 2
x2 = np.arange(0,8,1.5)
print(x2)
plt.plot(x2, x2**2, 'r+-', label='x^2')



#RESIZE graph
plt.figure(figsize=(5,3), dpi=500)

plt.savefig('mera graph' , dpi=1000)
# Out:
# [0.  1.5 3.  4.5 6.  7.5]

# %% [markdown]
# PLOT BAR

# %%
import matplotlib.pyplot as plt

LABELS = [4, 6, 8, 10, 12]
XAxis = [1, 4, 5, 7, 9]

plt.figure(figsize=(6, 4))
bars = plt.bar(LABELS, XAxis)

# Define hatch patterns
patterns = ('/', 'o', '*', '.', '\\')

# Assign hatch patterns to the bars
for bar, pattern in zip(bars, patterns):
    bar.set_hatch(pattern)

plt.xlabel('LABEL')
plt.ylabel('XAxis')
plt.title('Bar Chart with Hatch Patterns')

plt.show()
